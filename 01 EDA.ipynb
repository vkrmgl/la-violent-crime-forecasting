# %% [markdown]
# ## DATASCI 207: Machine Learning
# #### Project: Crime Classification Model for Community Policing
#
# **Dataset**: Crime Data from 2020 to Present
# **Source**: https://catalog.data.gov/dataset/crime-data-from-2020-to-present
#
# #### Project Description:
# This project develops a machine learning model to classify crimes as violent
# or non-violent based on feature analysis of crime data. The model aims to
# support data-driven community policing strategies and resource allocation.
#
# #### Team Members:
# - Kadin Wilkins
# - Matilda Orona
# - Vikram Magal
# - Anushka Vazirani

# %%
import pandas as pd
import numpy as np

# %%
# Read data
df = pd.read_csv('data/Crime_Data_from_2020_to_Present.csv')

# %%
# Display first 5 rows
df.head()
# Out:
#        DR_NO               Date Rptd                DATE OCC  TIME OCC  AREA  \
# 0  211507896  04/11/2021 12:00:00 AM  11/07/2020 12:00:00 AM       845    15
# 1  201516622  10/21/2020 12:00:00 AM  10/18/2020 12:00:00 AM      1845    15
# 2  240913563  12/10/2024 12:00:00 AM  10/30/2020 12:00:00 AM      1240     9
# 3  210704711  12/24/2020 12:00:00 AM  12/24/2020 12:00:00 AM      1310     7
# 4  201418201  10/03/2020 12:00:00 AM  09/29/2020 12:00:00 AM      1830    14
#
#      AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0  N Hollywood         1502         2     354
# 1  N Hollywood         1521         1     230
# 2     Van Nuys          933         2     354
# 3     Wilshire          782         1     331
# 4      Pacific         1454         1     420
#
#                                          Crm Cd Desc  ... Status  Status Desc  \
# 0                                  THEFT OF IDENTITY  ...     IC  Invest Cont
# 1     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT  ...     IC  Invest Cont
# 2                                  THEFT OF IDENTITY  ...     IC  Invest Cont
# 3  THEFT FROM MOTOR VEHICLE - GRAND ($950.01 AND ...  ...     IC  Invest Cont
# 4    THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)  ...     IC  Invest Cont
#
#   Crm Cd 1 Crm Cd 2  Crm Cd 3 Crm Cd 4  \
# 0    354.0      NaN       NaN      NaN
# 1    230.0      NaN       NaN      NaN
# 2    354.0      NaN       NaN      NaN
# 3    331.0      NaN       NaN      NaN
# 4    420.0      NaN       NaN      NaN
#
#                                    LOCATION Cross Street      LAT       LON
# 0   7800    BEEMAN                       AV          NaN  34.2124 -118.4092
# 1           ATOLL                        AV     N  GAULT  34.1993 -118.4203
# 2  14600    SYLVAN                       ST          NaN  34.1847 -118.4509
# 3   6000    COMEY                        AV          NaN  34.0339 -118.3747
# 4                   4700    LA VILLA MARINA          NaN  33.9813 -118.4350
#
# [5 rows x 28 columns]

# %%
# Look at unique Crime Descriptions where Weapon Used Code is NULL
df[df['Weapon Used Cd'].isnull()]['Crm Cd Desc'].unique()
# Out:
# array(['THEFT OF IDENTITY',
#        'THEFT FROM MOTOR VEHICLE - GRAND ($950.01 AND OVER)',
#        'THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)',
#        'VEHICLE - STOLEN', 'BURGLARY', 'BURGLARY FROM VEHICLE',
#        'THEFT PLAIN - PETTY ($950 & UNDER)',
#        'VANDALISM - MISDEAMEANOR ($399 OR UNDER)',
#        'VEHICLE - ATTEMPT STOLEN',
#        'VANDALISM - FELONY ($400 & OVER, ALL CHURCH VANDALISMS)',
#        'FIREARMS RESTRAINING ORDER (FIREARMS RO)', 'BIKE - STOLEN',
#        'EMBEZZLEMENT, GRAND THEFT ($950.01 & OVER)',
#        'THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LIVESTK,PROD',
#        'LETTERS, LEWD  -  TELEPHONE CALLS, LEWD',
#        'VIOLATION OF COURT ORDER', 'ARSON',
#        'VIOLATION OF RESTRAINING ORDER', 'CONTEMPT OF COURT',
#        'OTHER MISCELLANEOUS CRIME', 'TRESPASSING', 'BUNCO, ATTEMPT',
#        'SHOPLIFTING - PETTY THEFT ($950 & UNDER)', 'BURGLARY, ATTEMPTED',
#        'DOCUMENT FORGERY / STOLEN FELONY',
#        'SHOPLIFTING-GRAND THEFT ($950.01 & OVER)', 'FAILURE TO YIELD',
#        'VEHICLE, STOLEN - OTHER (MOTORIZED SCOOTERS, BIKES, ETC)',
#        'CHILD NEGLECT (SEE 300 W.I.C.)', 'BUNCO, GRAND THEFT',
#        'CONTRIBUTING', 'PIMPING',
#        'SEX OFFENDER REGISTRANT OUT OF COMPLIANCE', 'EXTORTION',
#        'BUNCO, PETTY THEFT', 'THEFT, PERSON',
#        'VIOLATION OF TEMPORARY RESTRAINING ORDER',
#        'CHILD ANNOYING (17YRS & UNDER)',
#        'BURGLARY FROM VEHICLE, ATTEMPTED',
#        'SEX,UNLAWFUL(INC MUTUAL CONSENT, PENETRATION W/ FRGN OBJ',
#        'LEWD CONDUCT', 'PICKPOCKET', 'INTIMATE PARTNER - SIMPLE ASSAULT',
#        'CHILD STEALING', 'PURSE SNATCHING',
#        'HUMAN TRAFFICKING - COMMERCIAL SEX ACTS', 'INDECENT EXPOSURE',
#        'DISHONEST EMPLOYEE - PETTY THEFT',
#        'EMBEZZLEMENT, PETTY THEFT ($950 & UNDER)',
#        'UNAUTHORIZED COMPUTER ACCESS', 'THEFT PLAIN - ATTEMPT',
#        'THEFT FROM MOTOR VEHICLE - ATTEMPT', 'RECKLESS DRIVING',
#        'SHOPLIFTING - ATTEMPT', 'DISTURBING THE PEACE',
#        'DRIVING WITHOUT OWNER CONSENT (DWOC)', 'PEEPING TOM',
#        'CRIMINAL THREATS - NO WEAPON DISPLAYED', 'FALSE POLICE REPORT',
#        'BOAT - STOLEN', 'OTHER ASSAULT',
#        'DEFRAUDING INNKEEPER/THEFT OF SERVICES, $950 & UNDER',
#        'ILLEGAL DUMPING', 'SEXUAL PENETRATION W/FOREIGN OBJECT',
#        'DRUGS, TO A MINOR', 'CHILD ABUSE (PHYSICAL) - SIMPLE ASSAULT',
#        'CREDIT CARDS, FRAUD USE ($950 & UNDER',
#        'THEFT, COIN MACHINE - ATTEMPT', 'PETTY THEFT - AUTO REPAIR',
#        'DOCUMENT WORTHLESS ($200 & UNDER)', 'FALSE IMPRISONMENT',
#        'CREDIT CARDS, FRAUD USE ($950.01 & OVER)',
#        'DEFRAUDING INNKEEPER/THEFT OF SERVICES, OVER $950.01',
#        'CHILD PORNOGRAPHY', 'PANDERING', 'CRUELTY TO ANIMALS',
#        'COUNTERFEIT', 'THEFT, COIN MACHINE - PETTY ($950 & UNDER)',
#        'LEWD/LASCIVIOUS ACTS WITH CHILD',
#        'DISHONEST EMPLOYEE - GRAND THEFT', 'PROWLER', 'RESISTING ARREST',
#        'DOCUMENT WORTHLESS ($200.01 & OVER)',
#        'THROWING OBJECT AT MOVING VEHICLE', 'GRAND THEFT / AUTO REPAIR',
#        'CONSPIRACY', 'THEFT FROM PERSON - ATTEMPT', 'DRUNK ROLL',
#        'HUMAN TRAFFICKING - INVOLUNTARY SERVITUDE',
#        'THEFT, COIN MACHINE - GRAND ($950.01 & OVER)', 'DISRUPT SCHOOL',
#        'TILL TAP - PETTY ($950 & UNDER)', 'PICKPOCKET, ATTEMPT',
#        'THREATENING PHONE CALLS/LETTERS', 'CRIMINAL HOMICIDE',
#        'GRAND THEFT / INSURANCE FRAUD',
#        'TILL TAP - GRAND THEFT ($950.01 & OVER)',
#        'DISCHARGE FIREARMS/SHOTS FIRED', 'ROBBERY',
#        'BIKE - ATTEMPTED STOLEN', 'BRIBERY', 'PURSE SNATCHING - ATTEMPT',
#        'CHILD ABANDONMENT', 'STALKING', 'BIGAMY', 'FAILURE TO DISPERSE',
#        'FIREARMS EMERGENCY PROTECTIVE ORDER (FIREARMS EPO)',
#        'BEASTIALITY, CRIME AGAINST NATURE SEXUAL ASSLT WITH ANIM',
#        'INCEST (SEXUAL ACTS BETWEEN BLOOD RELATIVES)',
#        'ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT',
#        'TELEPHONE PROPERTY - DAMAGE', 'BLOCKING DOOR INDUCTION CENTER',
#        'RAPE, FORCIBLE',
#        'REPLICA FIREARMS(SALE,DISPLAY,MANUFACTURE OR DISTRIBUTE)',
#        'INCITING A RIOT', 'DISHONEST EMPLOYEE ATTEMPTED THEFT',
#        'MANSLAUGHTER, NEGLIGENT', 'BATTERY - SIMPLE ASSAULT', 'LYNCHING',
#        'DRUNK ROLL - ATTEMPT'], dtype=object)

# %% [markdown]
# After exploring the list, some of the values in here look like they would qualify as a "Violent Crime". They are as follows:
# - 'CHILD ABUSE (PHYSICAL) - SIMPLE ASSAULT'
# - 'INTIMATE PARTNER - SIMPLE ASSAULT'
# - 'ROBBERY'
# - 'CRIMINAL HOMICIDE'
# - 'ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT'
# - 'RAPE, FORCIBLE'
# - 'MANSLAUGHTER, NEGLIGENT'
# - 'BATTERY - SIMPLE ASSAULT'
# - 'LYNCHING'

# %%
# Look at unique Crime Descriptions where Weapon Used Code is not NULL
df[df['Weapon Used Cd'].notnull()]['Crm Cd Desc'].unique()
# Out:
# array(['ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT',
#        'CRM AGNST CHLD (13 OR UNDER) (14-15 & SUSP 10 YRS OLDER)',
#        'INTIMATE PARTNER - SIMPLE ASSAULT', 'BATTERY - SIMPLE ASSAULT',
#        'BURGLARY', 'ROBBERY', 'CHILD ABUSE (PHYSICAL) - SIMPLE ASSAULT',
#        'CRIMINAL THREATS - NO WEAPON DISPLAYED',
#        'BATTERY WITH SEXUAL CONTACT', 'THEFT, PERSON',
#        'BURGLARY FROM VEHICLE', 'INTIMATE PARTNER - AGGRAVATED ASSAULT',
#        'VANDALISM - FELONY ($400 & OVER, ALL CHURCH VANDALISMS)',
#        'ATTEMPTED ROBBERY', 'LEWD/LASCIVIOUS ACTS WITH CHILD',
#        'BRANDISH WEAPON', 'BATTERY POLICE (SIMPLE)', 'ARSON',
#        'BIKE - STOLEN', 'RAPE, ATTEMPTED',
#        'VANDALISM - MISDEAMEANOR ($399 OR UNDER)',
#        'VIOLATION OF COURT ORDER', 'OTHER ASSAULT',
#        'THEFT PLAIN - PETTY ($950 & UNDER)',
#        'SODOMY/SEXUAL CONTACT B/W PENIS OF ONE PERS TO ANUS OTH',
#        'RAPE, FORCIBLE', 'DISCHARGE FIREARMS/SHOTS FIRED',
#        'SHOTS FIRED AT MOVING VEHICLE, TRAIN OR AIRCRAFT',
#        'ASSAULT WITH DEADLY WEAPON ON POLICE OFFICER', 'RESISTING ARREST',
#        'OTHER MISCELLANEOUS CRIME', 'SHOTS FIRED AT INHABITED DWELLING',
#        'THROWING OBJECT AT MOVING VEHICLE', 'ORAL COPULATION',
#        'SEXUAL PENETRATION W/FOREIGN OBJECT', 'BURGLARY, ATTEMPTED',
#        'VIOLATION OF RESTRAINING ORDER', 'TRESPASSING',
#        'CHILD NEGLECT (SEE 300 W.I.C.)',
#        'THEFT FROM MOTOR VEHICLE - ATTEMPT',
#        'THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)',
#        'CHILD ANNOYING (17YRS & UNDER)',
#        'THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LIVESTK,PROD',
#        'KIDNAPPING', 'DISTURBING THE PEACE', 'CRIMINAL HOMICIDE',
#        'REPLICA FIREARMS(SALE,DISPLAY,MANUFACTURE OR DISTRIBUTE)',
#        'LYNCHING', 'THREATENING PHONE CALLS/LETTERS',
#        'SEX,UNLAWFUL(INC MUTUAL CONSENT, PENETRATION W/ FRGN OBJ',
#        'BOMB SCARE', 'THEFT OF IDENTITY',
#        'CHILD ABUSE (PHYSICAL) - AGGRAVATED ASSAULT', 'STALKING',
#        'LETTERS, LEWD  -  TELEPHONE CALLS, LEWD',
#        'VEHICLE - ATTEMPT STOLEN', 'BATTERY ON A FIREFIGHTER',
#        'BUNCO, GRAND THEFT', 'EXTORTION', 'CHILD STEALING',
#        'CONTEMPT OF COURT', 'SHOPLIFTING - PETTY THEFT ($950 & UNDER)',
#        'PURSE SNATCHING', 'THEFT, COIN MACHINE - PETTY ($950 & UNDER)',
#        'BURGLARY FROM VEHICLE, ATTEMPTED', 'MANSLAUGHTER, NEGLIGENT',
#        'THEFT FROM PERSON - ATTEMPT', 'KIDNAPPING - GRAND ATTEMPT',
#        'THEFT FROM MOTOR VEHICLE - GRAND ($950.01 AND OVER)',
#        'FALSE IMPRISONMENT', 'HUMAN TRAFFICKING - INVOLUNTARY SERVITUDE',
#        'HUMAN TRAFFICKING - COMMERCIAL SEX ACTS', 'VEHICLE - STOLEN',
#        'INDECENT EXPOSURE', 'LEWD CONDUCT', 'THEFT PLAIN - ATTEMPT',
#        'SHOPLIFTING-GRAND THEFT ($950.01 & OVER)',
#        'WEAPONS POSSESSION/BOMBING', 'CRUELTY TO ANIMALS',
#        'VIOLATION OF TEMPORARY RESTRAINING ORDER',
#        'DEFRAUDING INNKEEPER/THEFT OF SERVICES, $950 & UNDER', 'PIMPING',
#        'SHOPLIFTING - ATTEMPT', 'PICKPOCKET', 'LYNCHING - ATTEMPTED',
#        'VEHICLE, STOLEN - OTHER (MOTORIZED SCOOTERS, BIKES, ETC)',
#        'DEFRAUDING INNKEEPER/THEFT OF SERVICES, OVER $950.01',
#        'DOCUMENT FORGERY / STOLEN FELONY', 'CONSPIRACY',
#        'BUNCO, PETTY THEFT', 'EMBEZZLEMENT, GRAND THEFT ($950.01 & OVER)',
#        'PURSE SNATCHING - ATTEMPT', 'RECKLESS DRIVING', 'PROWLER',
#        'FAILURE TO YIELD', 'THEFT, COIN MACHINE - GRAND ($950.01 & OVER)',
#        'EMBEZZLEMENT, PETTY THEFT ($950 & UNDER)', 'BUNCO, ATTEMPT',
#        'THEFT, COIN MACHINE - ATTEMPT',
#        'SEX OFFENDER REGISTRANT OUT OF COMPLIANCE',
#        'TELEPHONE PROPERTY - DAMAGE', 'PICKPOCKET, ATTEMPT',
#        'BEASTIALITY, CRIME AGAINST NATURE SEXUAL ASSLT WITH ANIM',
#        'PANDERING', 'UNAUTHORIZED COMPUTER ACCESS', 'FALSE POLICE REPORT',
#        'CHILD PORNOGRAPHY', 'PEEPING TOM', 'DISRUPT SCHOOL',
#        'FIREARMS EMERGENCY PROTECTIVE ORDER (FIREARMS EPO)',
#        'INCEST (SEXUAL ACTS BETWEEN BLOOD RELATIVES)',
#        'TILL TAP - PETTY ($950 & UNDER)', 'CHILD ABANDONMENT',
#        'CREDIT CARDS, FRAUD USE ($950 & UNDER',
#        'DRIVING WITHOUT OWNER CONSENT (DWOC)', 'COUNTERFEIT',
#        'CONTRIBUTING', 'DRUNK ROLL', 'INCITING A RIOT',
#        'DISHONEST EMPLOYEE - PETTY THEFT',
#        'GRAND THEFT / INSURANCE FRAUD', 'TRAIN WRECKING'], dtype=object)

# %% [markdown]
# All of these values look like they would qualify as a "Violent Crime".

# %%
# Check if DR_NO has any duplicates(This is supposed to be a unique ID)
df['DR_NO'].duplicated().any()
# Out:
# np.False_

# %%
# Display the percentage of NULLs in each Column
df.isnull().sum() / len(df) * 100
# Out:
# DR_NO              0.000000
# Date Rptd          0.000000
# DATE OCC           0.000000
# TIME OCC           0.000000
# AREA               0.000000
# AREA NAME          0.000000
# Rpt Dist No        0.000000
# Part 1-2           0.000000
# Crm Cd             0.000000
# Crm Cd Desc        0.000000
# Mocodes           15.086603
# Vict Age           0.000000
# Vict Sex          14.392567
# Vict Descent      14.393761
# Premis Cd          0.001592
# Premis Desc        0.058508
# Weapon Used Cd    67.437818
# Weapon Desc       67.437818
# Status             0.000100
# Status Desc        0.000000
# Crm Cd 1           0.001095
# Crm Cd 2          93.118346
# Crm Cd 3          99.769749
# Crm Cd 4          99.993632
# LOCATION           0.000000
# Cross Street      84.652997
# LAT                0.000000
# LON                0.000000
# dtype: float64

# %%
# Make a list of crimes that we identified as Violent from one of the previous steps
violent_crimes = ['CHILD ABUSE (PHYSICAL) - SIMPLE ASSAULT', 'INTIMATE PARTNER - SIMPLE ASSAULT', 'ROBBERY', 'CRIMINAL HOMICIDE', 'ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT', 'RAPE, FORCIBLE', 'MANSLAUGHTER, NEGLIGENT', 'BATTERY - SIMPLE ASSAULT', 'LYNCHING']

# Create a new Crime Type column with Violent and Non-Violent labels
df['Crime Type'] = np.where(df['Weapon Used Cd'].notnull() | df['Crm Cd Desc'].isin(violent_crimes), 'Violent', 'Non-Violent')

# %%
# Display the newly created labels alongside their corresponding Crime Descriptions
df[['Crm Cd Desc','Crime Type']]
# Out:
#                                                Crm Cd Desc   Crime Type
# 0                                        THEFT OF IDENTITY  Non-Violent
# 1           ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT      Violent
# 2                                        THEFT OF IDENTITY  Non-Violent
# 3        THEFT FROM MOTOR VEHICLE - GRAND ($950.01 AND ...  Non-Violent
# 4          THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)  Non-Violent
# ...                                                    ...          ...
# 1004986                          OTHER MISCELLANEOUS CRIME  Non-Violent
# 1004987                     CHILD NEGLECT (SEE 300 W.I.C.)  Non-Violent
# 1004988                                  INDECENT EXPOSURE  Non-Violent
# 1004989                           BATTERY - SIMPLE ASSAULT      Violent
# 1004990                                  INDECENT EXPOSURE  Non-Violent
#
# [1004991 rows x 2 columns]
