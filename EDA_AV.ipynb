# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
incidents_train = pd.read_csv("data/processed/train.csv")

# %%
# Correlation
cm = incidents_train[["crime_Violent", "violent_lag_1", "violent_lag_2", "violent_lag_3", "pop_total", "median_household_income", "gini_index", "unemployment_rate", "poverty_rate"]].corr()

hm = sns.heatmap(
    cm.values,
    yticklabels=cm.index,
    xticklabels=cm.columns,
    cmap = "Purples",
    center = 0,
    annot = True
)
plt.title("Correlation Matrix")
plt.show()

# %% [raw]
# #incidents_train.groupby("ZCTA").sum("crime_Violent").sort_values(by='crime_Violent', ascending=False)
# incidents_zcta = incidents_train.groupby("ZCTA").sum("crime_Violent")
#
# len(incidents_zcta[incidents_zcta["crime_Violent"] < 10])
# #incidents_zcta["crime_Violent"].describe()
# #incidents_zcta["crime_Violent"]
#
# # Plot distirbution of total crimes for each zip code
# # -- Lower end, maybe indicates that zip code is shared between LAPD and another police department
# # -- should we drop these? DATA CHALLENGE
# # --
#
# "violent_lag_1": "sum",
#     "violent_lag_2": "sum",
#     "violent_lag_3": "sum",

# %%
# Pairplot for lagging indicators
sns.pairplot(incidents_train[["crime_Violent", "violent_lag_1", "violent_lag_2", "violent_lag_3"]])

# %%
# Pairplot for ACS data
incidents_train_acs = incidents_train.groupby(["ZCTA"]).agg({
    "crime_Violent": "sum",
    "pop_total": "mean",
    "median_household_income": "mean",
    "gini_index": "mean",
    "unemployment_rate": "mean",
    "poverty_rate": "mean"
    }).reset_index()

sns.pairplot(incidents_train_acs.drop(["ZCTA"], axis = 1))
